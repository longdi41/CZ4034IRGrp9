# %%
import pysolr
from nltk.tokenize import word_tokenize
import re
import pandas
import requests

try:
    solr = pysolr.Solr('http://localhost:8983/solr/CZ4034')
    solr.ping() #test connection 
except Exception as e:
    if "Failed to connect to server" in str(e):
        print("No solr installed/running")
    elif "HTTP 404" in str(e):
        print("Core CZ4034 doesnt exist")
    else:
        print(e)

# %%
def import_csv(csv):
    success = True
    csv.drop_duplicates(subset=['Tweet Id'], keep='last')
    for i in range(len(csv)):
        try:
            hashtags = []
            if type(csv.iloc()[i]['Hashtags']) == "str":
                hashtags = csv.iloc()[i]['Hashtags']
                hashtags = re.sub(r"[\[\]']+", "",hashtags).replace(' ','')
                hashtags = hashtags.split(",")

            temp = {
                'tweet_id' : str(csv.iloc()[i]['Tweet Id']),
                'created_at' : csv.iloc()[i]['Datetime'].replace(' ','T').replace('+00:00','Z'),
                'username' : csv.iloc()[i]['Username'],
                'content' : csv.iloc()[i]['Text'],
                'hashtags' : hashtags,
                'likes' : int(csv.iloc()[i]['Like(s)']),
                'retweet' : int(csv.iloc()[i]['Retweet(s)']),
                'latlon' : str(csv.iloc()[i]['Latitude']) + ',' + str(csv.iloc()[i]['Longitude'])
            }

            solr.add(temp)
        except:
            success = False
            print("Cannot upload tweet", i)
    solr.commit()
    if success:
        return "Success"
    else:
        return "Failed"

# %%
def search(search_str, page_no = 1, result_per_page = 10):
    query_string = search_str
    page_no = page_no - 1 #default start is 0
    
    params = {
        'df': 'content',
        'rows': result_per_page,
        'start': page_no,
        'spellcheck': 'true'
    }

    search_results = solr.search(query_string, search_handler='select',**params)
    collations = []
    if search_results.spellcheck.keys():
        collations = list(filter(lambda a: a != 'collation', search_results.spellcheck['collations']))
    
    return search_results.docs, search_results.hits, collations

# %%
def delete_all():
    solr.delete(q="*:*")
    solr.commit()
    
def autocomplete_phase(phase):
    #return a list of tuples, tuple: [0] = term, [1] term freq
    #autocomplete = solr.suggest_terms("content", term)
    query_string = phase.rstrip()
    search_results = solr.search(query_string, search_handler='suggest')
    return search_results.raw_response['suggest']['default'][query_string]['suggestions']

def similar_search(text):
    similar = solr.more_like_this('content:'+text, mltfl='content')
    return similar.docs

# %%
def location_search(coordinates, search_radius = 5, result_per_page = 10):    
    params = {
        'fq': '{!geofilt}',
        'sfield': 'latlon',
        'pt': coordinates,
        'd': search_radius,
        'sort': 'geodist() asc',
        'rows': result_per_page
        #'start': page_no
    }

    search_results = solr.search("*:*", search_handler='select',**params)
    
    return search_results.docs, search_results.hits

# %% [markdown]
# # Below For Testing

# %%
tweets = pandas.read_csv (r'crawled_tweets_geo.csv')
tweets = tweets.drop_duplicates(subset=['Tweet Id'], keep='last')
print(tweets.keys())

tweets_tokens = []
for i in range(len(tweets)): 
    check_words = ' '.join(re.sub("([@#][A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweets.iloc()[i]['Text']).split())
    text_tokens = word_tokenize(re.sub(r"\S*https?:\S*", "", check_words))
    tweets_tokens = tweets_tokens + text_tokens

print("No of records:",len(tweets))
print("No of words:",len(tweets_tokens))
print("No of unique words:",len(set(tweets_tokens)))
# Out:
# Index(['Datetime', 'Tweet Id', 'Text', 'Username', 'Hashtags', 'Like(s)',
#        'Reply(s)', 'Retweet(s)', 'Search term', 'Coordinates', 'Latitude',
#        'Longitude'],
#       dtype='object')
# No of records: 12181
# No of words: 301706
# No of unique words: 22104

# %%
delete_all()
import_csv(tweets)
# Out:
# 'Success'

# %%
pip install PySimpleGUI
# Out:
# Collecting PySimpleGUI
#   Downloading PySimpleGUI-4.57.0-py3-none-any.whl (491 kB)
#      |████████████████████████████████| 491 kB 4.3 MB/s eta 0:00:01
# Installing collected packages: PySimpleGUI
# Successfully installed PySimpleGUI-4.57.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import PySimpleGUI as sg
from IPython.display import clear_output

sg.theme("DarkBlue3")
sg.set_options(font=("Courier New", 16))

layout = [
    [sg.Input("")],
    [sg.Button('Cancel')]
]
window = sg.Window('Title', layout, return_keyboard_events=True, use_default_focus=False)
select = ''

while True:
    clear_output(wait=True)
    event, values = window.read()
    if event == sg.WINDOW_CLOSED or event == 'Cancel' :
        break
    elif len(event) == 1 and ord(event) == 13:
        (r1,r2,r3) = search(select)
        print(r1)
        break
    if event is not None:
        # example to use autocomplete
        # phases enclose in <b></b> is what you typed
        # only bold enclose if suggestion starts with typed words
        autocomplete = autocomplete_phase(values[0])
        if len(autocomplete)>0:
            select = autocomplete[0]["term"]
            print("suggestions")
            for au in autocomplete:
                print(au["term"])
        else:
            print("Nothing")
window.close()
# Out:
# suggestions
# <b>k</b>yiv
# <b>k</b>now
# <b>k</b>yiv ukraine
# <b>k</b>yiv ukraine https t.co
# <b>k</b>yiv ukraine https
# photo kyiv ukraine https
# photo kyiv ukraine
# photo kyiv
# a photo kyiv ukraine
# a photo kyiv

# %%
print(similar_search("Four years ago this morning in Kyiv / Kiev. Happier times. Stay safe my Ukrainian friends. 🇺🇦 @ Kyiv, Ukraine https://t.co/fpeqnl08lm"))
# Out:
# [{'created_at': '2022-03-02T11:45:28Z', 'username': 'na3ar', 'content': 'from #kyiv with love\n\n#uaразом @ Kyiv, Ukraine https://t.co/6uKjNMyyQ4', 'content_suggest': ['from #kyiv with love\n\n#uaразом @ Kyiv, Ukraine https://t.co/6uKjNMyyQ4'], 'likes': 0, 'retweet': 0, 'latlon': '50.45,30.52361111', 'id': 'dd9a3597-717b-4498-a8a9-0ceb387c073f', 'tweet_id': '1498987852192833536', '_version_': 1729162241589116928}, {'created_at': '2022-02-24T10:34:38Z', 'username': 'reigner_7', 'content': 'We are safe here #kyiv #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/9IJq8nglAD', 'content_suggest': ['We are safe here #kyiv #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/9IJq8nglAD'], 'likes': 0, 'retweet': 0, 'latlon': '50.45,30.52361111', 'id': 'a4e50ed4-211f-4270-8fbb-1f8d643a2a6a', 'tweet_id': '1496795700566372357', '_version_': 1729162230548660224}, {'created_at': '2022-03-10T10:28:14Z', 'username': 'FreeManReporter', 'content': 'Surveying damage near the #Kyiv TV tower @ Kyiv, Ukraine https://t.co/KJSuPQVvPO', 'content_suggest': ['Surveying damage near the #Kyiv TV tower @ Kyiv, Ukraine https://t.co/KJSuPQVvPO'], 'likes': 1, 'retweet': 0, 'latlon': '50.45,30.52361111', 'id': '4e8cc311-4839-457a-8eb7-af07e9a0bd7c', 'tweet_id': '1501867518893379587', '_version_': 1729162249071755264}, {'created_at': '2022-02-24T13:45:41Z', 'username': 'SimonJNewbury', 'content': 'Beautiful Kyiv. Beautiful Ukraine. My thoughts are with you. Stop this war. #ukraine #kyiv #democracy #freedom #solidarity #ukraina #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/RWoDWWmW4g', 'content_suggest': ['Beautiful Kyiv. Beautiful Ukraine. My thoughts are with you. Stop this war. #ukraine #kyiv #democracy #freedom #solidarity #ukraina #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/RWoDWWmW4g'], 'likes': 0, 'retweet': 0, 'latlon': '50.45,30.52361111', 'id': 'e9da7357-6eae-43fc-9916-11d8f3119d5d', 'tweet_id': '1496843780044910592', '_version_': 1729162230520348672}, {'created_at': '2022-03-09T00:22:04Z', 'username': 'PhraAthit', 'content': '#UkraineRussianWar #Kyiv #UkraineTroops\nBBC News - War in Ukraine: Troops dig in near Kyiv\nhttps://t.co/NvOE6octlm', 'content_suggest': ['#UkraineRussianWar #Kyiv #UkraineTroops\nBBC News - War in Ukraine: Troops dig in near Kyiv\nhttps://t.co/NvOE6octlm'], 'likes': 3, 'retweet': 1, 'latlon': '52.338079,13.088304', 'id': 'ad57ac5d-e3a7-4b1e-81cc-8da5b414a160', 'tweet_id': '1501352582584803330', '_version_': 1729162248560050176}, {'created_at': '2022-03-03T23:58:35Z', 'username': 'asmartt1', 'content': 'Churches of Kyiv.\nPhotos taken during my visit in 2017.\n🇺🇦🕊️🌻\n\n#ukraine #kyiv #standwithukraine #freedom #peace #travel #democracy #architecture #religion #church @ Kyiv, Ukraine https://t.co/DPf9peddPz', 'content_suggest': ['Churches of Kyiv.\nPhotos taken during my visit in 2017.\n🇺🇦🕊️🌻\n\n#ukraine #kyiv #standwithukraine #freedom #peace #travel #democracy #architecture #religion #church @ Kyiv, Ukraine https://t.co/DPf9peddPz'], 'likes': 2, 'retweet': 2, 'latlon': '50.45,30.52361111', 'id': '9f6eeba0-bad6-4577-b0e3-59a738d2f1b5', 'tweet_id': '1499534733704941571', '_version_': 1729162242672295936}, {'created_at': '2022-02-26T05:16:56Z', 'username': 'WFLAJosh', 'content': 'Kids jammed into a safe zone in the Ukrainian capital of #Kyiv. (via Olexander Scherba) #Russia #Ukraine @ Kyiv https://t.co/QJJUuNTnUa', 'content_suggest': ['Kids jammed into a safe zone in the Ukrainian capital of #Kyiv. (via Olexander Scherba) #Russia #Ukraine @ Kyiv https://t.co/QJJUuNTnUa'], 'likes': 39, 'retweet': 5, 'latlon': '50.43815102,30.51668146', 'id': 'b90c11e1-a855-4ead-a956-74b252d8ddd8', 'tweet_id': '1497440522025193473', '_version_': 1729162218134568960}, {'created_at': '2022-03-11T11:03:40Z', 'username': 'FreeManReporter', 'content': 'Refugee transit center for people fleeing Horenka, a village in the #Kyiv region near Irpin @ Kyiv, Ukraine https://t.co/hu23aZTMyz', 'content_suggest': ['Refugee transit center for people fleeing Horenka, a village in the #Kyiv region n ...

# %%
search("kiv russio")
# Out:
# ([],
#  0,
#  ['kyiv russia', 'ki v russia', 'kyiv russi o', 'ki v russi o', 'kiev russia'])

# %%
location_search('50.45,30.52361111',5,281)
# Out:
# ([{'created_at': '2022-02-24T21:36:08Z',
#    'username': 'MilwaukeeAndy',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/uhGTOj36bC',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/uhGTOj36bC'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'ec5f65b4-08f8-44b1-99da-f693f4cc2823',
#    'tweet_id': '1496962172441747461',
#    '_version_': 1728691931636039680},
#   {'created_at': '2022-02-24T20:50:11Z',
#    'username': 'krixmeister',
#    'content': 'I don’t have words for the emotions I feel for my friends and colleagues in Ukraine. Please do know that the world is thinking of you, I truly hope the governments of USA and Europe do the right thing, and be safe. https://t.co/tKPh6vl6VE',
#    'content_suggest': ['I don’t have words for the emotions I feel for my friends and colleagues in Ukraine. Please do know that the world is thinking of you, I truly hope the governments of USA and Europe do the right thing, and be safe. https://t.co/tKPh6vl6VE'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '8b69255f-4729-47a5-b28e-abf1af1a5c5d',
#    'tweet_id': '1496950606178705414',
#    '_version_': 1728691931641282560},
#   {'created_at': '2022-02-24T20:21:02Z',
#    'username': 'ScratcherHead',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/gIdyRE1X4B',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/gIdyRE1X4B'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '4f05f3ca-a98d-4c63-b06d-7d55dca407cf',
#    'tweet_id': '1496943271687376896',
#    '_version_': 1728691931649671168},
#   {'created_at': '2022-02-24T19:10:21Z',
#    'username': 'captainkernow',
#    'content': 'I visited Kyiv, Ukraine in 2019.  My thoughts and wishes are with the Ukrainians I met, and the rest of the people of that wonderful country. #istandwithukraine #ukraine @ Kyiv, Ukraine https://t.co/vfl2qJEm2O',
#    'content_suggest': ['I visited Kyiv, Ukraine in 2019.  My thoughts and wishes are with the Ukrainians I met, and the rest of the people of that wonderful country. #istandwithukraine #ukraine @ Kyiv, Ukraine https://t.co/vfl2qJEm2O'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'f8df24fd-2f3e-4333-ae18-c39674f85bc9',
#    'tweet_id': '1496925481869856789',
#    '_version_': 1728691931669594112},
#   {'created_at': '2022-02-24T18:57:59Z',
#    'username': 'iteachwhile',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/IrVm3Pfqs2',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/IrVm3Pfqs2'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '9e001808-afbf-42d9-855e-88cad868bda0',
#    'tweet_id': '1496922370145140736',
#    '_version_': 1728691931673788416},
#   {'created_at': '2022-02-24T17:45:51Z',
#    'username': 'onlineammostore',
#    'content': 'Our thoughts and prayers are with you, Ukraine 🇺🇦 #prayforukraine #ukraine #ukrainetoday #peacenotwar #violenceisnottheanswer #protectyourlovedones #antiwar @ Kyiv, Ukraine https://t.co/mHiaqh6ZKA',
#    'content_suggest': ['Our thoughts and prayers are with you, Ukraine 🇺🇦 #prayforukraine #ukraine #ukrainetoday #peacenotwar #violenceisnottheanswer #protectyourlovedones #antiwar @ Kyiv, Ukraine https://t.co/mHiaqh6ZKA'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'f349154a-7f55-438f-a049-b995619fc2b6',
#    'tweet_id': '1496904219605020674',
#    '_version_': 1728691931689517056},
#   {'created_at': '2022-02-24T17:41:06Z',
#    'username': 'sharpasabrick',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/Ro7YPjTHr5',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/Ro7YPjTHr5'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'f8efdefc-2a02-4bb5-85fa-49a00c6f3f3d',
#    'tweet_id': '1496903023293087745',
#    '_version_': 1728691931694759936},
#   {'created_at': '2022-02-24T16:21:04Z',
#    'username': 'djshirkhan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/p66igp6s5y',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/p66igp6s5y'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '0977e794-6611-45a0-93ae-934778521c64',
#    'tweet_id': '1496882883860045828',
#    '_version_': 1728691931704197120},
#   {'created_at': '2022-02-24T15:41:33Z',
#    'username': 'daniellismore',
#    'content': 'To my friends in Ukraine my love is with you. I love your beautiful country. You deserve peace. My time in Ukraine with you all has a special place in my heart. LOVE 🇺🇦🇺🇦🇺🇦🇺🇦 @ Kyiv, Ukraine https://t.co/x8HfEegmhM',
#    'content_suggest': ['To my friends in Ukraine my love is with you. I love your beautiful country. You deserve peace. My time in Ukraine with you all has a special place in my heart. LOVE 🇺🇦🇺🇦🇺🇦🇺🇦 @ Kyiv, Ukraine https://t.co/x8HfEegmhM'],
#    'likes': 4,
#    'retweet': 1,
#    'latlon': '50.45,30.52361111',
#    'id': 'cf2ad8fb-fab3-4835-bd0b-62923adb8177',
#    'tweet_id': '1496872939312013322',
#    '_version_': 1728691931713634304},
#   {'created_at': '2022-02-24T15:29:13Z',
#    'username': 'exploitedrec',
#    'content': 'This is a terrible and sad day.  We stand with Ukraine and pray for our friends in Kyiv. 🙏 This crazy war must be stopped. Support Ukraine! @ Kyiv, Ukraine https://t.co/2rUtNpUr06',
#    'content_suggest': ['This is a terrible and sad day.  We stand with Ukraine and pray for our friends in Kyiv. 🙏 This crazy war must be stopped. Support Ukraine! @ Kyiv, Ukraine https://t.co/2rUtNpUr06'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '54c5ce0d-4577-4e7f-abe7-c99f5df7bd5d',
#    'tweet_id': '1496869832532402180',
#    '_version_': 1728691931718877184},
#   {'created_at': '2022-02-24T15:07:28Z',
#    'username': 'chubby_charlton',
#    'content': 'My son and his mate Asif in Kyiv 5 years ago. #prayforukraine 🙏🏼🇺🇦 @ Kyiv, Ukraine https://t.co/RBFuLY86QN',
#    'content_suggest': ['My son and his mate Asif in Kyiv 5 years ago. #prayforukraine 🙏🏼🇺🇦 @ Kyiv, Ukraine https://t.co/RBFuLY86QN'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'c4ac3375-6717-4a66-9699-857434b4c2e3',
#    'tweet_id': '1496864358953013252',
#    '_version_': 1728691931723071488},
#   {'created_at': '2022-02-24T15:04:32Z',
#    'username': 'emiliowcolon',
#    'content': 'Prayers for Ukraine. The world needs Peace to grow. War destroys world economies and humanity as a whole. @ Kyiv, Ukraine https://t.co/H0uuwIQBTX',
#    'content_suggest': ['Prayers for Ukraine. The world needs Peace to grow. War destroys world economies and humanity as a whole. @ Kyiv, Ukraine https://t.co/H0uuwIQBTX'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '2d0b7531-b940-42d7-ad61-c980325baa5e',
#    'tweet_id': '1496863621707702277',
#    '_version_': 1728691931728314368},
#   {'created_at': '2022-02-24T14:28:49Z',
#    'username': 'TamarahLight',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/9ZwxcO6zLi',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/9ZwxcO6zLi'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'f2173afa-63f5-4479-ad7a-700b31a6dc9f',
#    'tweet_id': '1496854631741333506',
#    '_version_': 1728691931737751552},
#   {'created_at': '2022-02-24T14:04:26Z',
#    'username': 'chillosophia',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/7Uijsl2SdR',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/7Uijsl2SdR'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '601bac82-5a63-40c8-bcbc-b2d9ad990fb6',
#    'tweet_id': '1496848496443412480',
#    '_version_': 1728691931741945856},
#   {'created_at': '2022-02-24T13:45:41Z',
#    'username': 'SimonJNewbury',
#    'content': 'Beautiful Kyiv. Beautiful Ukraine. My thoughts are with you. Stop this war. #ukraine #kyiv #democracy #freedom #solidarity #ukraina #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/RWoDWWmW4g',
#    'content_suggest': ['Beautiful Kyiv. Beautiful Ukraine. My thoughts are with you. Stop this war. #ukraine #kyiv #democracy #freedom #solidarity #ukraina #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/RWoDWWmW4g'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '125d6ee7-84db-4c99-8c59-43670c7f7160',
#    'tweet_id': '1496843780044910592',
#    '_version_': 1728691931752431616},
#   {'created_at': '2022-02-24T13:09:53Z',
#    'username': 'jennaleejames',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/AlPYtkFBBp',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/AlPYtkFBBp'],
#    'likes': 4,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '9bb0075f-6d1a-4c87-b97e-4c102bc5d968',
#    'tweet_id': '1496834767266140160',
#    '_version_': 1728691931756625920},
#   {'created_at': '2022-02-24T12:26:13Z',
#    'username': 'daniellismore',
#    'content': 'My friends in Ukraine. My thoughts are with you. You do not deserve this Russian monsters insanity. I love you all. I love your beautiful country and my time with you all has a special place in my heart. 🇺🇦🇺🇦🇺🇦🇺🇦🇺🇦 https://t.co/swjeNKxy9c',
#    'content_suggest': ['My friends in Ukraine. My thoughts are with you. You do not deserve this Russian monsters insanity. I love you all. I love your beautiful country and my time with you all has a special place in my heart. 🇺🇦🇺🇦🇺🇦🇺🇦🇺🇦 https://t.co/swjeNKxy9c'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '07c39efb-8316-4bc5-b95a-b830bcf057eb',
#    'tweet_id': '1496823780219490314',
#    '_version_': 1728691931770257408},
#   {'created_at': '2022-02-24T12:08:03Z',
#    'username': 'LeCompteanaluc',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/L9nVHGwtV0',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/L9nVHGwtV0'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '70e3a344-0e0f-4fc1-8ff8-803cbbe16495',
#    'tweet_id': '1496819207358631937',
#    '_version_': 1728691931775500288},
#   {'created_at': '2022-02-24T11:28:41Z',
#    'username': 'LozsLeisure',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/CUG5sDDfYp',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/CUG5sDDfYp'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '6d4e8ac0-6988-4aa3-a5e5-278de9a3daf0',
#    'tweet_id': '1496809299984596993',
#    '_version_': 1728691931779694592},
#   {'created_at': '2022-02-24T10:34:38Z',
#    'username': 'reigner_7',
#    'content': 'We are safe here #kyiv #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/9IJq8nglAD',
#    'content_suggest': ['We are safe here #kyiv #ukraine🇺🇦 @ Kyiv, Ukraine https://t.co/9IJq8nglAD'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'bf2f5f19-ee1a-4b55-8b04-992dca4ddf9d',
#    'tweet_id': '1496795700566372357',
#    '_version_': 1728691931794374656},
#   {'created_at': '2022-02-24T07:30:09Z',
#    'username': 'pj_kent',
#    'content': 'Four years ago this morning in Kyiv / Kiev. Happier times. Stay safe my Ukrainian friends. 🇺🇦 @ Kyiv, Ukraine https://t.co/fpeqnl08lm',
#    'content_suggest': ['Four years ago this morning in Kyiv / Kiev. Happier times. Stay safe my Ukrainian friends. 🇺🇦 @ Kyiv, Ukraine https://t.co/fpeqnl08lm'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '202478db-97ee-4b83-9a91-6030818cbbd1',
#    'tweet_id': '1496749271257075712',
#    '_version_': 1728691931827929088},
#   {'created_at': '2022-02-24T07:15:20Z',
#    'username': 'Alex_Shelest',
#    'content': "It's crazy, it's insane! God bless Ukraine! That's a real war! No jokes. \n.\n#ukraine #kyiv #world #war @ Kyiv, Ukraine https://t.co/tqoj8wVJi1",
#    'content_suggest': ["It's crazy, it's insane! God bless Ukraine! That's a real war! No jokes. \n.\n#ukraine #kyiv #world #war @ Kyiv, Ukraine https://t.co/tqoj8wVJi1"],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '5fda16cc-887c-4e87-a120-506c419f10ca',
#    'tweet_id': '1496745543170625536',
#    '_version_': 1728691931837366272},
#   {'created_at': '2022-02-25T23:18:32Z',
#    'username': 'MarioS2009',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/2tQtw7uDAj',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/2tQtw7uDAj'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'fa306b3d-87c3-4695-a6f4-88f3da451e0e',
#    'tweet_id': '1497350328773140490',
#    '_version_': 1728691932889088000},
#   {'created_at': '2022-02-25T20:11:16Z',
#    'username': 'PerschkeMichael',
#    'content': '#Stopwar @safeukraine @stop_putin_freedom_ukraine enough is enough !\nThe West needs to act NOW ! @ Kyiv, Ukraine https://t.co/GyUX6mEwqh',
#    'content_suggest': ['#Stopwar @safeukraine @stop_putin_freedom_ukraine enough is enough !\nThe West needs to act NOW ! @ Kyiv, Ukraine https://t.co/GyUX6mEwqh'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'a220f73a-f2d8-4ae8-ab2d-4005e8de948d',
#    'tweet_id': '1497303201783111693',
#    '_version_': 1728691932901670912},
#   {'created_at': '2022-02-25T19:25:31Z',
#    'username': 'Quluzade_Terlan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/z0wmlpnj7E',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/z0wmlpnj7E'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '68bca24c-67e0-4d42-b9d0-419e22805cbb',
#    'tweet_id': '1497291688343183360',
#    '_version_': 1728691932906913792},
#   {'created_at': '2022-02-25T19:25:06Z',
#    'username': 'fudurich',
#    'content': 'A Ukrainian Soldier’s last words in response to a Russian battleship telling them to surrender. @ Kyiv, Ukraine https://t.co/VxY8KZdxSt',
#    'content_suggest': ['A Ukrainian Soldier’s last words in response to a Russian battleship telling them to surrender. @ Kyiv, Ukraine https://t.co/VxY8KZdxSt'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '4a81181a-cee0-4993-a447-bc1a1189f6dc',
#    'tweet_id': '1497291584055959557',
#    '_version_': 1728691932912156672},
#   {'created_at': '2022-02-25T19:04:49Z',
#    'username': 'AMMASSURYA',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/S3cyYQ0cuW',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/S3cyYQ0cuW'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '4f7c1050-e1dd-4e9e-b840-67499fc5bb75',
#    'tweet_id': '1497286479881523201',
#    '_version_': 1728691932916350976},
#   {'created_at': '2022-02-25T18:36:56Z',
#    'username': 'bajanreporter',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/UGlsg30sDw',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/UGlsg30sDw'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'b3e2dcd9-b377-4364-a847-bb37534cf8b8',
#    'tweet_id': '1497279463142289412',
#    '_version_': 1728691932925788160},
#   {'created_at': '2022-02-25T18:35:43Z',
#    'username': 'emiliowcolon',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/mVOh2q8mNS',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/mVOh2q8mNS'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '8c47011b-638c-4beb-8276-20f7d39e0443',
#    'tweet_id': '1497279156043853825',
#    '_version_': 1728691932932079616},
#   {'created_at': '2022-02-25T18:28:50Z',
#    'username': 'Quluzade_Terlan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/NkTWuPwmKB',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/NkTWuPwmKB'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '755048fd-660c-44d1-9355-354e3f5876b9',
#    'tweet_id': '1497277424005902336',
#    '_version_': 1728691932936273920},
#   {'created_at': '2022-02-25T17:42:01Z',
#    'username': 'Sti_Stanislav',
#    'content': 'War in Ukraine.  Russia is an aggressor #warinukraine #russuanaggression #ukraine #россияагрессор #войнаукраина (Kyiv, Ukraine): https://t.co/ufsZBYDbSo',
#    'content_suggest': ['War in Ukraine.  Russia is an aggressor #warinukraine #russuanaggression #ukraine #россияагрессор #войнаукраина (Kyiv, Ukraine): https://t.co/ufsZBYDbSo'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '974086e7-2f2d-46ea-bd75-b28cc7e0071d',
#    'tweet_id': '1497265643527233541',
#    '_version_': 1728691932946759680},
#   {'created_at': '2022-02-25T17:13:46Z',
#    'username': 'aidaessaid',
#    'content': 'Pics from my trip to the Ukraine in 2015.\n#istandwithukraine #ukraine 🇺🇦 #standwithukraine @ Kyiv, Ukraine https://t.co/kfbzcESdGo',
#    'content_suggest': ['Pics from my trip to the Ukraine in 2015.\n#istandwithukraine #ukraine 🇺🇦 #standwithukraine @ Kyiv, Ukraine https://t.co/kfbzcESdGo'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'ba827403-eea5-49c9-b530-c38109cb89a8',
#    'tweet_id': '1497258534387339266',
#    '_version_': 1728691932956196864},
#   {'created_at': '2022-02-25T16:22:12Z',
#    'username': 'lidiyaflaks',
#    'content': 'Windows of my sister’s apartment in Kiev. In 2022. The sovereign democratic country is being annihilated by totalitarian dictatorship while the world is silently watching… #Ukraine @ Kyiv, Ukraine https://t.co/d04hZ8Rjtl',
#    'content_suggest': ['Windows of my sister’s apartment in Kiev. In 2022. The sovereign democratic country is being annihilated by totalitarian dictatorship while the world is silently watching… #Ukraine @ Kyiv, Ukraine https://t.co/d04hZ8Rjtl'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '8d6c0956-a062-4162-a296-61a95e1083d5',
#    'tweet_id': '1497245554052632579',
#    '_version_': 1728691932961439744},
#   {'created_at': '2022-02-25T16:16:50Z',
#    'username': 'grantjhugh',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/M5FpF1Kk3L',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/M5FpF1Kk3L'],
#    'likes': 1,
#    'retweet': 1,
#    'latlon': '50.45,30.52361111',
#    'id': '5367c017-b815-48d6-aeb1-190531251f64',
#    'tweet_id': '1497244206217138182',
#    '_version_': 1728691932967731200},
#   {'created_at': '2022-02-25T16:10:25Z',
#    'username': 'JayCalvertMD',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/2KUB0ESGUJ',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/2KUB0ESGUJ'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'c6d14841-c1ed-458f-bb1f-60d841e3c18b',
#    'tweet_id': '1497242590588149801',
#    '_version_': 1728691932972974080},
#   {'created_at': '2022-02-25T16:10:13Z',
#    'username': 'lestatv6',
#    'content': 'I stand with the people of Ukraine ❤️ @ Kyiv, Ukraine https://t.co/GPbZStwSdI',
#    'content_suggest': ['I stand with the people of Ukraine ❤️ @ Kyiv, Ukraine https://t.co/GPbZStwSdI'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '494ee20d-255f-4ad0-a5fb-8d0fead6403b',
#    'tweet_id': '1497242537803005962',
#    '_version_': 1728691932979265536},
#   {'created_at': '2022-02-25T15:30:41Z',
#    'username': 'LuvTheSouth',
#    'content': 'I stand with the people of Ukraine 🇺🇦 @ Kyiv, Ukraine https://t.co/2V37Lfgie5',
#    'content_suggest': ['I stand with the people of Ukraine 🇺🇦 @ Kyiv, Ukraine https://t.co/2V37Lfgie5'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '1b8eb070-b8d2-4c74-b34e-ea176cf8cb5d',
#    'tweet_id': '1497232589500952578',
#    '_version_': 1728691932983459840},
#   {'created_at': '2022-02-25T13:48:34Z',
#    'username': 'monicabcurca',
#    'content': '#peace is possible in #Ukraine and #russia. Praying for creativity and a moral imagination for our leaders. War is not the answer. #romanianartist #peacebuilding #leadership #war #ukrainerussiaconflict @ Kyiv, Ukraine https://t.co/q1bHP2GL6k',
#    'content_suggest': ['#peace is possible in #Ukraine and #russia. Praying for creativity and a moral imagination for our leaders. War is not the answer. #romanianartist #peacebuilding #leadership #war #ukrainerussiaconflict @ Kyiv, Ukraine https://t.co/q1bHP2GL6k'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '35c024e0-b797-4b24-bae8-7081ecd6bccc',
#    'tweet_id': '1497206893860765708',
#    '_version_': 1728691932988702720},
#   {'created_at': '2022-02-25T13:47:02Z',
#    'username': 'wylyastley',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/Qz7MtvquBU',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/Qz7MtvquBU'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'f107fb33-b825-4750-9c64-358f951bb2e4',
#    'tweet_id': '1497206506319659026',
#    '_version_': 1728691932993945600},
#   {'created_at': '2022-02-25T13:32:34Z',
#    'username': 'LilianaM_Actor',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/pYOgOD9ibJ',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/pYOgOD9ibJ'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'b10ba331-a77b-4984-8f3b-66bb32970f38',
#    'tweet_id': '1497202865235968015',
#    '_version_': 1728691932998139904},
#   {'created_at': '2022-02-25T13:06:39Z',
#    'username': 'ducatipaul',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/BxKgQOQSDG',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/BxKgQOQSDG'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'ab38376d-fef9-4ac1-87bc-02e00c93ee63',
#    'tweet_id': '1497196343537901572',
#    '_version_': 1728691933002334208},
#   {'created_at': '2022-02-25T11:17:47Z',
#    'username': 'realVladFreedom',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/2YfhWEHzAN',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/2YfhWEHzAN'],
#    'likes': 4,
#    'retweet': 1,
#    'latlon': '50.45,30.52361111',
#    'id': '29d97c94-bb00-480c-ac01-c6a3e190161d',
#    'tweet_id': '1497168945060716560',
#    '_version_': 1728691933015965696},
#   {'created_at': '2022-02-25T11:01:39Z',
#    'username': 'ronhaviv',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/zDTdGqyRrV',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/zDTdGqyRrV'],
#    'likes': 15,
#    'retweet': 2,
#    'latlon': '50.45,30.52361111',
#    'id': '27687fd2-629c-4f8e-9c20-fa1175c398d8',
#    'tweet_id': '1497164885964333056',
#    '_version_': 1728691933021208576},
#   {'created_at': '2022-02-25T09:14:36Z',
#    'username': 'ruidooo',
#    'content': 'Current days Nativity scene @ Kyiv, Ukraine https://t.co/HIc0sdBISu',
#    'content_suggest': ['Current days Nativity scene @ Kyiv, Ukraine https://t.co/HIc0sdBISu'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'b30f4d69-85f5-4f3d-b327-45f302878cd4',
#    'tweet_id': '1497137946679468055',
#    '_version_': 1728691933034840064},
#   {'created_at': '2022-02-25T07:14:23Z',
#    'username': 'Scoobyscottie',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/k1u1guYgK1',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/k1u1guYgK1'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '7c33b201-7cf6-49fb-b250-b8cc5a07c7ef',
#    'tweet_id': '1497107691000545311',
#    '_version_': 1728691933057908736},
#   {'created_at': '2022-02-25T06:27:00Z',
#    'username': 'amylfrazer',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/FquQGgmL9g',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/FquQGgmL9g'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'b21723d4-f787-4e34-9dfe-54f3deb712ac',
#    'tweet_id': '1497095768586571777',
#    '_version_': 1728691933063151616},
#   {'created_at': '2022-02-25T04:30:45Z',
#    'username': 'UT_mish3al',
#    'content': "You know I'm trash so...... You're welcome. #austin #ukraine #russia @ Kyiv, Ukraine https://t.co/jYCoGtRnIY",
#    'content_suggest': ["You know I'm trash so...... You're welcome. #austin #ukraine #russia @ Kyiv, Ukraine https://t.co/jYCoGtRnIY"],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'b5dfd72d-9d30-4615-ad85-026dbe61fab8',
#    'tweet_id': '1497066511315390506',
#    '_version_': 1728691933075734528},
#   {'created_at': '2022-02-25T04:28:22Z',
#    'username': 'LindseyFoard',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/M4Ymww0W6v',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/M4Ymww0W6v'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '7ad492c3-7039-4c65-bd2c-4c3d56ad90a3',
#    'tweet_id': '1497065911139799042',
#    '_version_': 1728691933080977408},
#   {'created_at': '2022-02-25T04:27:29Z',
#    'username': 'UT_mish3al',
#    'content': "You know I'm trash, so here you go...... #russia #ukraine #austin #usa @ Kyiv, Ukraine https://t.co/5Bb3zC9iG7",
#    'content_suggest': ["You know I'm trash, so here you go...... #russia #ukraine #austin #usa @ Kyiv, Ukraine https://t.co/5Bb3zC9iG7"],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'd876ba23-d2fc-4e0c-bec8-b059ac0b1fbf',
#    'tweet_id': '1497065689739587585',
#    '_version_': 1728691933085171712},
#   {'created_at': '2022-02-25T04:13:17Z',
#    'username': 'Bibblast',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/mqk6Ez97t5',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/mqk6Ez97t5'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'e6e1b557-8910-4de4-9242-748a3c121283',
#    'tweet_id': '1497062117563850757',
#    '_version_': 1728691933090414592},
#   {'created_at': '2022-02-25T03:52:08Z',
#    'username': 'chancewalters',
#    'content': 'Within the Kingdom of God, it’s not them, it’s us. \n\nLet’s make a commitment to pray for our brothers and sisters in Ukraine...\n\n#matthew24 #cwmi #prayingforukraine @ Kyiv, Ukraine https://t.co/8GWrKQ82r8',
#    'content_suggest': ['Within the Kingdom of God, it’s not them, it’s us. \n\nLet’s make a commitment to pray for our brothers and sisters in Ukraine...\n\n#matthew24 #cwmi #prayingforukraine @ Kyiv, Ukraine https://t.co/8GWrKQ82r8'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '78094df3-de96-4f0c-8ab8-0d440cb37984',
#    'tweet_id': '1497056792764981249',
#    '_version_': 1728691933094608896},
#   {'created_at': '2022-02-25T03:05:21Z',
#    'username': 'alisoltani',
#    'content': 'Hey Schmuck 🤡I can assist you with your knowledge gaps in geography \n\n#ukraine 🇺🇦 #standwithukraine @ Kyiv, Ukraine https://t.co/15O5g3IrMa',
#    'content_suggest': ['Hey Schmuck 🤡I can assist you with your knowledge gaps in geography \n\n#ukraine 🇺🇦 #standwithukraine @ Kyiv, Ukraine https://t.co/15O5g3IrMa'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '8710eba2-5eda-44c5-be36-7d2cbda0fb85',
#    'tweet_id': '1497045019781476367',
#    '_version_': 1728691933108240384},
#   {'created_at': '2022-02-25T02:52:03Z',
#    'username': 'RikkiRockett',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/skghwR6fzZ',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/skghwR6fzZ'],
#    'likes': 32,
#    'retweet': 2,
#    'latlon': '50.45,30.52361111',
#    'id': '89d29e13-d414-42ed-b4ab-0460eb6f1c4c',
#    'tweet_id': '1497041672357613568',
#    '_version_': 1728691933112434688},
#   {'created_at': '2022-02-26T18:02:38Z',
#    'username': 'Quluzade_Terlan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/O84euneHJ9',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/O84euneHJ9'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '30d37f89-ac4c-4ac2-b2f7-2813cdc8413b',
#    'tweet_id': '1497633216022339587',
#    '_version_': 1728691934424203264},
#   {'created_at': '2022-02-26T17:21:45Z',
#    'username': 'firehaus',
#    'content': 'And you think your commute is bad…\n.\n.\n#freeukraine #nomorewar #ukraine @ Kyiv, Ukraine https://t.co/sjSXmizrSq',
#    'content_suggest': ['And you think your commute is bad…\n.\n.\n#freeukraine #nomorewar #ukraine @ Kyiv, Ukraine https://t.co/sjSXmizrSq'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '5059862e-8d9b-4735-9852-f55b2d488f6f',
#    'tweet_id': '1497622930179641352',
#    '_version_': 1728691934429446144},
#   {'created_at': '2022-02-26T16:35:23Z',
#    'username': 'evnschoustudios',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/R85DkQnFl1',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/R85DkQnFl1'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '6c659cc9-2801-45f7-9e68-92fa552d1e1d',
#    'tweet_id': '1497611262267740163',
#    '_version_': 1728691934433640448},
#   {'created_at': '2022-02-26T16:04:53Z',
#    'username': 'AziaCelestino',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/ftvtlHhnBx',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/ftvtlHhnBx'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'c93caac3-1eff-4fdd-9277-d467b95670c0',
#    'tweet_id': '1497603586431369223',
#    '_version_': 1728691934437834752},
#   {'created_at': '2022-02-26T12:56:40Z',
#    'username': 'daninstockholm',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/kJclhAhibG',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/kJclhAhibG'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '40b76264-eed2-4f87-971d-874198a1ac33',
#    'tweet_id': '1497556220525219844',
#    '_version_': 1728691934469292032},
#   {'created_at': '2022-02-26T11:27:57Z',
#    'username': 'iAlexander13',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/rRv2mzZOE3',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/rRv2mzZOE3'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'c01e123e-e191-4c8d-904f-4a16da679d84',
#    'tweet_id': '1497533893951508485',
#    '_version_': 1728691934503895040},
#   {'created_at': '2022-02-26T10:57:58Z',
#    'username': 'LeoQueirozBJJ',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/9NuF2tPMc8',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/9NuF2tPMc8'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'ce2f5ed5-3065-4fdd-8dac-98c5a112dbcd',
#    'tweet_id': '1497526348423864320',
#    '_version_': 1728691934511235072},
#   {'created_at': '2022-02-26T10:23:00Z',
#    'username': 'ravindimaria7',
#    'content': 'My heart goes with love, prayers and support for Ukraine❤️🇺🇦🕊️ @ Kyiv, Ukraine https://t.co/KtRNL2hv4s',
#    'content_suggest': ['My heart goes with love, prayers and support for Ukraine❤️🇺🇦🕊️ @ Kyiv, Ukraine https://t.co/KtRNL2hv4s'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '4e8fab0d-b525-4da2-8a68-4be548f8a7a3',
#    'tweet_id': '1497517548870459392',
#    '_version_': 1728691934523817984},
#   {'created_at': '2022-02-26T08:28:07Z',
#    'username': 'hookmfc',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/eEq89x6gcG',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/eEq89x6gcG'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '17d6ff97-8178-41c6-b7bb-43ebf7db4f6d',
#    'tweet_id': '1497488636387860482',
#    '_version_': 1728691934543740928},
#   {'created_at': '2022-02-26T07:23:28Z',
#    'username': 'alisoltani',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/0BPpKRMhZV',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/0BPpKRMhZV'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '9307c290-3bb3-496c-b201-749b24ccf36a',
#    'tweet_id': '1497472367823622150',
#    '_version_': 1728691934553178112},
#   {'created_at': '2022-02-26T07:06:34Z',
#    'username': 'icklemidgie',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/ZD9OpxbNpz',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/ZD9OpxbNpz'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '7f32d69f-23bc-4f58-b8a3-27a78ff19e36',
#    'tweet_id': '1497468112740012032',
#    '_version_': 1728691934558420992},
#   {'created_at': '2022-02-26T06:19:25Z',
#    'username': 'EmilChynn',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/dMVYthrVGV',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/dMVYthrVGV'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '8f6d2944-c0d7-40df-9d9e-a2b6bb0f7930',
#    'tweet_id': '1497456249486684162',
#    '_version_': 1728691934563663872},
#   {'created_at': '2022-02-26T05:26:13Z',
#    'username': 'Mike_Steinbock',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/pQN37c6PuI',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/pQN37c6PuI'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '65c24ae4-943a-4bc3-97b5-956f5255c5b1',
#    'tweet_id': '1497442859175358466',
#    '_version_': 1728691934571003904},
#   {'created_at': '2022-02-26T03:56:36Z',
#    'username': 'StarsRugby7s',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/6XzBRdCFm4',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/6XzBRdCFm4'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '96eef507-5f75-48f8-b6cf-c99b73be0ab5',
#    'tweet_id': '1497420308172898305',
#    '_version_': 1728691934586732544},
#   {'created_at': '2022-02-27T12:59:14Z',
#    'username': 'Annetaki',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/Hm1XoXw7vY',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/Hm1XoXw7vY'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '200b4edd-12d3-478a-b2ff-57cea00806de',
#    'tweet_id': '1497919253747539971',
#    '_version_': 1728691935997067264},
#   {'created_at': '2022-02-27T12:44:57Z',
#    'username': 'DublinPJ',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/3zPQDWR9Wg',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/3zPQDWR9Wg'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '0f5e16c5-a5a5-4c49-b56d-cbc62abdc936',
#    'tweet_id': '1497915659078053888',
#    '_version_': 1728691936002310144},
#   {'created_at': '2022-02-27T09:36:23Z',
#    'username': 'kelvinzehot',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/QfTMK6Prbe',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/QfTMK6Prbe'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'c11023d8-7e3b-471c-acda-d8c6644ec4ba',
#    'tweet_id': '1497868204735041536',
#    '_version_': 1728691936015941632},
#   {'created_at': '2022-02-26T23:32:21Z',
#    'username': 'MichaelWTravels',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/Ue16jKU1dy',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/Ue16jKU1dy'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '15ab74ea-91eb-42b1-9029-88020510b31f',
#    'tweet_id': '1497716193662324737',
#    '_version_': 1728691936039010304},
#   {'created_at': '2022-02-26T22:10:54Z',
#    'username': 'tracysmith1010',
#    'content': 'Just posted a video @ Kyiv, Ukraine https://t.co/fhGOUWU1KP',
#    'content_suggest': ['Just posted a video @ Kyiv, Ukraine https://t.co/fhGOUWU1KP'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '52eff682-54e7-46cb-9ab2-4d820632045d',
#    'tweet_id': '1497695694316048387',
#    '_version_': 1728691936043204608},
#   {'created_at': '2022-02-26T21:11:40Z',
#    'username': 'EmilChynn',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/Ywnq561dry',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/Ywnq561dry'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'b290cc76-9be2-4615-852e-cda7a45060b6',
#    'tweet_id': '1497680788195725314',
#    '_version_': 1728691936057884672},
#   {'created_at': '2022-02-26T20:21:23Z',
#    'username': 'Ninocence',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/gIPhPL7kPr',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/gIPhPL7kPr'],
#    'likes': 3,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '65018098-908e-40c3-bf6b-f13696f5e3a2',
#    'tweet_id': '1497668136530858000',
#    '_version_': 1728691936071516160},
#   {'created_at': '2022-02-26T20:16:55Z',
#    'username': 'Quluzade_Terlan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/6UaYMIu5lq',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/6UaYMIu5lq'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'ce798b4d-f69f-48ce-ae58-6607629e3d66',
#    'tweet_id': '1497667013115846659',
#    '_version_': 1728691936076759040},
#   {'created_at': '2022-02-26T19:52:50Z',
#    'username': 'Quluzade_Terlan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/sggAu80eTJ',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/sggAu80eTJ'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '383bb9a4-bf6e-4de8-aa20-50dd2637436b',
#    'tweet_id': '1497660951163715584',
#    '_version_': 1728691936085147648},
#   {'created_at': '2022-02-26T19:47:56Z',
#    'username': 'robtheleader',
#    'content': 'Just posted a video @ Kyiv, Ukraine https://t.co/YsBDdFLUG4',
#    'content_suggest': ['Just posted a video @ Kyiv, Ukraine https://t.co/YsBDdFLUG4'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '5d23afb4-0cd4-4c8c-acea-511831739dfa',
#    'tweet_id': '1497659717505662985',
#    '_version_': 1728691936090390528},
#   {'created_at': '2022-02-26T19:39:35Z',
#    'username': 'lidiyaflaks',
#    'content': 'From my sister in Kiev. They refuse to leave the city. #ukraine @ Kyiv, Ukraine https://t.co/3hmgsXfgjZ',
#    'content_suggest': ['From my sister in Kiev. They refuse to leave the city. #ukraine @ Kyiv, Ukraine https://t.co/3hmgsXfgjZ'],
#    'likes': 3,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '888f42f3-8caa-4f30-b49f-bd3d2dd69aaa',
#    'tweet_id': '1497657617145077767',
#    '_version_': 1728691936094584832},
#   {'created_at': '2022-02-26T19:38:54Z',
#    'username': 'laureanomestra',
#    'content': 'A quantum of solace. @ Kyiv, Ukraine https://t.co/XOzw4PZwLH',
#    'content_suggest': ['A quantum of solace. @ Kyiv, Ukraine https://t.co/XOzw4PZwLH'],
#    'likes': 2,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'c1135e44-39d2-4450-a99d-42630060e040',
#    'tweet_id': '1497657443425439754',
#    '_version_': 1728691936098779136},
#   {'created_at': '2022-02-26T19:36:53Z',
#    'username': 'ricflomusic',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/0iUiGhfKGe',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/0iUiGhfKGe'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '54497522-f4b6-46a9-898e-a264db07ca63',
#    'tweet_id': '1497656937537748998',
#    '_version_': 1728691936104022016},
#   {'created_at': '2022-02-26T19:36:31Z',
#    'username': 'Quluzade_Terlan',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/7C3mgXXP6a',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/7C3mgXXP6a'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '1df728c8-c5f1-4ab4-8ceb-da80d7e208a9',
#    'tweet_id': '1497656846068424709',
#    '_version_': 1728691936108216320},
#   {'created_at': '2022-02-26T19:24:56Z',
#    'username': 'kentegod',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/pnZOid7Cg0',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/pnZOid7Cg0'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '6a7d76d6-1833-4388-a207-a64dc005482c',
#    'tweet_id': '1497653929810792454',
#    '_version_': 1728691936117653504},
#   {'created_at': '2022-02-26T18:08:13Z',
#    'username': 'itsmuzza2004',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/YFV2nqali5',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/YFV2nqali5'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'ab60e4fe-3393-4de4-9ed6-2d4b681f3f07',
#    'tweet_id': '1497634624251514882',
#    '_version_': 1728691936127090688},
#   {'created_at': '2022-02-28T17:05:47Z',
#    'username': 'MunchkinsWell',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/D844CTnDAz',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/D844CTnDAz'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '0b58ad6d-35ab-4635-9d06-7306462e9a14',
#    'tweet_id': '1498343685968257025',
#    '_version_': 1728691937270038528},
#   {'created_at': '2022-02-28T12:14:23Z',
#    'username': 'monstruktor',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/p6kAfS9AX6',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/p6kAfS9AX6'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'f41c72e9-e0be-410f-b931-1beea99b1661',
#    'tweet_id': '1498270354669805571',
#    '_version_': 1728691937288912896},
#   {'created_at': '2022-02-28T11:34:17Z',
#    'username': 'A2A_Air2Air',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/xO4XbBKplq',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/xO4XbBKplq'],
#    'likes': 4,
#    'retweet': 1,
#    'latlon': '50.45,30.52361111',
#    'id': '8282673e-2b17-4a2d-afc1-7889bef0e5ed',
#    'tweet_id': '1498260262981414915',
#    '_version_': 1728691937294155776},
#   {'created_at': '2022-02-28T11:31:14Z',
#    'username': 'len_smith',
#    'content': 'What a great response. @ Kyiv, Ukraine https://t.co/8gnVKLMfZg',
#    'content_suggest': ['What a great response. @ Kyiv, Ukraine https://t.co/8gnVKLMfZg'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'a39fe22e-fbea-4740-95ae-67e7b63987d6',
#    'tweet_id': '1498259494542974976',
#    '_version_': 1728691937298350080},
#   {'created_at': '2022-02-28T09:40:49Z',
#    'username': 'BrookesBlossoms',
#    'content': 'This broken glass breaks our hearts! Please help us reach these kids. They are already fighting for their lives against cancer! #PRAYforUkraine #BrookesBlossoms #Hope4Cc #sendHOPE 🙏🏻🎗💛🇺🇦 @ Kyiv, Ukraine https://t.co/RrxcHkS2mo',
#    'content_suggest': ['This broken glass breaks our hearts! Please help us reach these kids. They are already fighting for their lives against cancer! #PRAYforUkraine #BrookesBlossoms #Hope4Cc #sendHOPE 🙏🏻🎗💛🇺🇦 @ Kyiv, Ukraine https://t.co/RrxcHkS2mo'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '93ff935d-a5fe-462f-aa76-e193461a60de',
#    'tweet_id': '1498231705567694855',
#    '_version_': 1728691937302544384},
#   {'created_at': '2022-02-28T08:52:51Z',
#    'username': 'traveltourqueen',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/FL80islM0W',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/FL80islM0W'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '2425270c-aed6-4d27-937d-6c552a83ec5a',
#    'tweet_id': '1498219637871464452',
#    '_version_': 1728691937313030144},
#   {'created_at': '2022-02-28T02:05:22Z',
#    'username': 'u2lavation',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/FHJcVUvmEb',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/FHJcVUvmEb'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '8bfa9642-f208-4375-bf40-0c8584132985',
#    'tweet_id': '1498117088694710275',
#    '_version_': 1728691937322467328},
#   {'created_at': '2022-02-28T01:54:01Z',
#    'username': 'eifanone',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/HJ3D56PJj4',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/HJ3D56PJj4'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '39a5c636-0d64-43d2-ae8e-d33fb4f67ae1',
#    'tweet_id': '1498114232180609027',
#    '_version_': 1728691937326661632},
#   {'created_at': '2022-02-28T01:13:06Z',
#    'username': 'vivavox',
#    'content': 'Look at this. Big monkey with nuclear bomb CANNOT kill small one!!!! @ Kyiv, Ukraine https://t.co/L6Om6q98Vp',
#    'content_suggest': ['Look at this. Big monkey with nuclear bomb CANNOT kill small one!!!! @ Kyiv, Ukraine https://t.co/L6Om6q98Vp'],
#    'likes': 2,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '76c5cb3d-835a-4a35-8ec1-94d6d636a803',
#    'tweet_id': '1498103935680356354',
#    '_version_': 1728691937330855936},
#   {'created_at': '2022-02-28T00:29:41Z',
#    'username': 'monstruktor',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/69LBF5uI3t',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/69LBF5uI3t'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '9696b88c-c75b-4a67-8a44-ee796c6b8321',
#    'tweet_id': '1498093011535896577',
#    '_version_': 1728691937336098816},
#   {'created_at': '2022-02-28T00:06:00Z',
#    'username': 'JaneCowanWax',
#    'content': 'Peace and Safety for the People of Ukraine. @ Kyiv, Ukraine https://t.co/6gnRCDAfoQ',
#    'content_suggest': ['Peace and Safety for the People of Ukraine. @ Kyiv, Ukraine https://t.co/6gnRCDAfoQ'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '377e3e4a-e8af-4e6a-9f04-f889674c8676',
#    'tweet_id': '1498087050465136641',
#    '_version_': 1728691937340293120},
#   {'created_at': '2022-02-27T22:53:06Z',
#    'username': 'MBulentSirin',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/AXyofaClX9',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/AXyofaClX9'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': 'e301e7cd-19ba-4f35-b2aa-145b3d324fe6',
#    'tweet_id': '1498068702654251014',
#    '_version_': 1728691937349730304},
#   {'created_at': '2022-02-27T22:17:06Z',
#    'username': 'BenjaminNerding',
#    'content': 'Just posted a photo @ Kyiv, Ukraine https://t.co/qJVIQkHDv9',
#    'content_suggest': ['Just posted a photo @ Kyiv, Ukraine https://t.co/qJVIQkHDv9'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '231bdf13-4e96-4261-9637-59a589c23d8e',
#    'tweet_id': '1498059646052945923',
#    '_version_': 1728691937353924608},
#   {'created_at': '2022-02-27T22:11:14Z',
#    'username': 'dynohuntermusic',
#    'content': 'Appalled by what’s happening in Ukraine, please consider donating to support Ukrainians in this dire time of need  (link in bio) #ukrainewillresist #putinisawarcriminal @ Kyiv, Ukraine https://t.co/Pz3Q5NVlfa',
#    'content_suggest': ['Appalled by what’s happening in Ukraine, please consider donating to support Ukrainians in this dire time of need  (link in bio) #ukrainewillresist #putinisawarcriminal @ Kyiv, Ukraine https://t.co/Pz3Q5NVlfa'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '2d4b3ce5-b673-4f10-865f-d85356c61d38',
#    'tweet_id': '1498058168668237824',
#    '_version_': 1728691937359167488},
#   {'created_at': '2022-02-27T21:49:06Z',
#    'username': 'Tremis_Dynamics',
#    'content': "It's something to see conservative right suck Bidens dick and just keep begging for a nice spunk facial. He really did unite people. @ Kyiv, Ukraine https://t.co/q49DPvzhIv",
#    'content_suggest': ["It's something to see conservative right suck Bidens dick and just keep begging for a nice spunk facial. He really did unite people. @ Kyiv, Ukraine https://t.co/q49DPvzhIv"],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45,30.52361111',
#    'id': '42f2ad9a-807c-4848-875e-ab9429562dd7',
#    'tweet_id': '1498052598754066433',
#    '_version_': 1728691937363361792},
#   {'created_at': '2022-02-27T21:45:50Z',
#    'username': 'TheKrisMadden',
# ...
#    'likes': 2,
#    'retweet': 0,
#    'latlon': '50.43815102,30.51668146',
#    'id': '5aa27359-51fd-4ab0-8714-9c67646cf217',
#    'tweet_id': '1497502878386249730',
#    '_version_': 1728691934537449472},
#   {'created_at': '2022-02-26T05:16:56Z',
#    'username': 'WFLAJosh',
#    'content': 'Kids jammed into a safe zone in the Ukrainian capital of #Kyiv. (via Olexander Scherba) #Russia #Ukraine @ Kyiv https://t.co/QJJUuNTnUa',
#    'content_suggest': ['Kids jammed into a safe zone in the Ukrainian capital of #Kyiv. (via Olexander Scherba) #Russia #Ukraine @ Kyiv https://t.co/QJJUuNTnUa'],
#    'likes': 39,
#    'retweet': 5,
#    'latlon': '50.43815102,30.51668146',
#    'id': '0426cd90-b166-4c44-8a47-5e26713b4f90',
#    'tweet_id': '1497440522025193473',
#    '_version_': 1728691934578343936},
#   {'created_at': '2022-03-01T19:51:24Z',
#    'username': 'lastminutenewst',
#    'content': "Kiev'de TV kulesinin vurulma anı. #Ukriane #Rusya #Ruble Takipte kalın!\n\nThe moment of the shooting of the TV tower in Kiev. #Ukriane #Russia #Ruble Stay tuned! Support by sharing. @ Kiev City Ukranian https://t.co/AGZPyBDj9s",
#    'content_suggest': ["Kiev'de TV kulesinin vurulma anı. #Ukriane #Rusya #Ruble Takipte kalın!\n\nThe moment of the shooting of the TV tower in Kiev. #Ukriane #Russia #Ruble Stay tuned! Support by sharing. @ Kiev City Ukranian https://t.co/AGZPyBDj9s"],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': 'b5f1450b-3022-42fa-8c71-201387710ce5',
#    'tweet_id': '1498747751642718208',
#    '_version_': 1728691929207537664},
#   {'created_at': '2022-02-26T15:06:42Z',
#    'username': 'LGTNetworkNY',
#    'content': 'I , personally, love Russia and their people. For that… Russians, please time to leash and curb your dog. #NoWar.!! \n\n…” Good Neighbors Curb their Dogs …” THANK YOU @ Kiev City Ukranian https://t.co/1MgG6Y3T4N',
#    'content_suggest': ['I , personally, love Russia and their people. For that… Russians, please time to leash and curb your dog. #NoWar.!! \n\n…” Good Neighbors Curb their Dogs …” THANK YOU @ Kiev City Ukranian https://t.co/1MgG6Y3T4N'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': '348406c8-ab94-47c9-b3c5-446434e4ef99',
#    'tweet_id': '1497588944564850692',
#    '_version_': 1728691929242140672},
#   {'created_at': '2022-02-26T23:36:26Z',
#    'username': 'dhessex007',
#    'content': 'Pray for Ukraine ❤️❤️❤️ @ Kiev City Ukranian https://t.co/ZvYuP6QdNy',
#    'content_suggest': ['Pray for Ukraine ❤️❤️❤️ @ Kiev City Ukranian https://t.co/ZvYuP6QdNy'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': '3920a73f-ee5b-441e-a729-5aca011392cd',
#    'tweet_id': '1497717223204569089',
#    '_version_': 1728691936034816000},
#   {'created_at': '2022-03-01T20:13:48Z',
#    'username': 'dhessex007',
#    'content': 'God bless Ukraine @ Kiev City Ukranian https://t.co/jm9U11YsHY',
#    'content_suggest': ['God bless Ukraine @ Kiev City Ukranian https://t.co/jm9U11YsHY'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': 'cc01d7e9-85ab-416d-9ade-d6727d206511',
#    'tweet_id': '1498753390326734858',
#    '_version_': 1728691941630017536},
#   {'created_at': '2022-03-01T18:43:50Z',
#    'username': 'HusaynMekki',
#    'content': 'Perspective.\n\n#Ukraine @ Kiev City Ukranian https://t.co/8y5CBLvz7S',
#    'content_suggest': ['Perspective.\n\n#Ukraine @ Kiev City Ukranian https://t.co/8y5CBLvz7S'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': 'ff23b0ac-0445-4c5d-9533-9b5bd78dd293',
#    'tweet_id': '1498730751185010689',
#    '_version_': 1728691941673009152},
#   {'created_at': '2022-03-03T06:33:44Z',
#    'username': 'lastminutenewst',
#    'content': '#BREAKING: Massive explosion reported in Kyiv, Ukraine tonight following Russian airstrikes. @ Kiev City Ukranian https://t.co/T4yzFR1bh8',
#    'content_suggest': ['#BREAKING: Massive explosion reported in Kyiv, Ukraine tonight following Russian airstrikes. @ Kiev City Ukranian https://t.co/T4yzFR1bh8'],
#    'likes': 1,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': '35bd62e6-8e51-485c-8a88-78d21a6b39c5',
#    'tweet_id': '1499271790778068993',
#    '_version_': 1728691943980924928},
#   {'created_at': '2022-03-02T20:25:01Z',
#    'username': 'lastminutenewst',
#    'content': 'Stop the innocent lives getting killed..STOP THE WAR PUTIN 💔🙏\n#StopWar #StopTheWar #Stopthewarputin #UkraineInvasion #Ukraine @ Kiev City Ukranian https://t.co/thrGXzaKof',
#    'content_suggest': ['Stop the innocent lives getting killed..STOP THE WAR PUTIN 💔🙏\n#StopWar #StopTheWar #Stopthewarputin #UkraineInvasion #Ukraine @ Kiev City Ukranian https://t.co/thrGXzaKof'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.44642647,30.49625699',
#    'id': '57e4884a-fee9-4d86-8f6a-d0656690916f',
#    'tweet_id': '1499118601906769921',
#    '_version_': 1728691944024965120},
#   {'created_at': '2022-02-26T20:30:01Z',
#    'username': 'Liveuamap',
#    'content': 'According to the Ministry of Defense, during the three days of the Russian invasion of Ukraine: more than 210 civilians were killed, including six children; ; more than 1,100 people were injured or injured, including more than 100 children https://t.co/ueFBByKaoV  #Ukraine',
#    'content_suggest': ['According to the Ministry of Defense, during the three days of the Russian invasion of Ukraine: more than 210 civilians were killed, including six children; ; more than 1,100 people were injured or injured, including more than 100 children https://t.co/ueFBByKaoV  #Ukraine'],
#    'likes': 327,
#    'retweet': 126,
#    'latlon': '50.4469,30.49015',
#    'id': '87525979-e951-4fb6-b063-6becbb0a829b',
#    'tweet_id': '1497670308932816898',
#    '_version_': 1728691936067321856},
#   {'created_at': '2022-02-27T16:53:38Z',
#    'username': 'Dorofeyeff',
#    'content': '@karanewman Have your book here with me by the way. So. Nemiroff. Russian sources of Nemiroff vodka: Bashspirt (they have at least three distilleries in Bashkorstan - region in Asian part of Russia), some unnamed dstlrs of RosSpirtProm and in Belarus - distillery Minsk Kristall. https://t.co/fAg2n4pzUn',
#    'content_suggest': ['@karanewman Have your book here with me by the way. So. Nemiroff. Russian sources of Nemiroff vodka: Bashspirt (they have at least three distilleries in Bashkorstan - region in Asian part of Russia), some unnamed dstlrs of RosSpirtProm and in Belarus - distillery Minsk Kristall. https://t.co/fAg2n4pzUn'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.42754114707748,30.538781172524377',
#    'id': 'ac6962ca-938a-450b-96af-421bd8fb837e',
#    'tweet_id': '1497978239599489029',
#    '_version_': 1728691929230606336},
#   {'created_at': '2022-02-25T09:49:21Z',
#    'username': 'YounzanJ',
#    'content': "Dear NATO where are you ???\nAt the beginning, America was the 1st who said they are along with Ukraine but where are you now?Really this is happening ?? \nWhere is France ,Finland, Turkey,USA,Australia..??As a foreigner ,situated in Ukraine kyiv I don't think i will alive😰😰🙏🙏",
#    'content_suggest': ["Dear NATO where are you ???\nAt the beginning, America was the 1st who said they are along with Ukraine but where are you now?Really this is happening ?? \nWhere is France ,Finland, Turkey,USA,Australia..??As a foreigner ,situated in Ukraine kyiv I don't think i will alive😰😰🙏🙏"],
#    'likes': 4,
#    'retweet': 0,
#    'latlon': '50.47433016393735,30.513937254276772',
#    'id': 'ac72858e-6a19-44bb-9f02-1d75552edccb',
#    'tweet_id': '1497146689689432083',
#    '_version_': 1728691949887553536},
#   {'created_at': '2022-02-24T22:50:05Z',
#    'username': 'AlessioDevPool',
#    'content': 'Looking at some pictures from my trip to #Ukraine 🇺🇦 a few years ago. Such a beautiful country full of nice people. It was a great experience and it breaks my heart 💔 seeing these terrible images today. My condolences to all the innocent victims 🙏 https://t.co/L6YFFcrzUU',
#    'content_suggest': ['Looking at some pictures from my trip to #Ukraine 🇺🇦 a few years ago. Such a beautiful country full of nice people. It was a great experience and it breaks my heart 💔 seeing these terrible images today. My condolences to all the innocent victims 🙏 https://t.co/L6YFFcrzUU'],
#    'likes': 4,
#    'retweet': 0,
#    'latlon': '50.434411237559864,30.5564546585083',
#    'id': 'da6de882-164c-43a8-9a16-b1ecc56ee752',
#    'tweet_id': '1496980782698672129',
#    '_version_': 1728691931624505344},
#   {'created_at': '2022-02-28T14:44:32Z',
#    'username': 'blindedbtlight',
#    'content': 'I love Kyiv. Spending time there was one of the privileges of my life. \n\nYou underestimate the character, pride and dignity of the Ukrainian people at your peril.\n\nSlava Ukraini 🇺🇦\n\n(Kyievo-Pecherska Lavra, Kyiv, Ukraine. 10 April 2018) https://t.co/bALVkzELA4',
#    'content_suggest': ['I love Kyiv. Spending time there was one of the privileges of my life. \n\nYou underestimate the character, pride and dignity of the Ukrainian people at your peril.\n\nSlava Ukraini 🇺🇦\n\n(Kyievo-Pecherska Lavra, Kyiv, Ukraine. 10 April 2018) https://t.co/bALVkzELA4'],
#    'likes': 4,
#    'retweet': 0,
#    'latlon': '50.434411237559864,30.5564546585083',
#    'id': 'e38d0114-b343-4dce-92ff-e19cd3ade8ce',
#    'tweet_id': '1498308140252774404',
#    '_version_': 1728691937279475712},
#   {'created_at': '2022-02-25T20:40:33Z',
#    'username': 'Liveuamap',
#    'content': 'Heavy explosions rocking Kyiv, air raid sirens sounding https://t.co/EmARjbJk8K via @ELINTNews #Ukraine',
#    'content_suggest': ['Heavy explosions rocking Kyiv, air raid sirens sounding https://t.co/EmARjbJk8K via @ELINTNews #Ukraine'],
#    'likes': 255,
#    'retweet': 96,
#    'latlon': '50.454440000000005,30.5674',
#    'id': '3aeaa623-9379-431b-ad2e-c249d401edbf',
#    'tweet_id': '1497310570088960006',
#    '_version_': 1728691932897476608},
#   {'created_at': '2022-03-02T07:53:04Z',
#    'username': 'Liveuamap',
#    'content': 'Minister of Defense of Ukraine: "New BayraktarTB2s have already arrived in Ukraine and are at combat positions https://t.co/46ahoqzxMd via @clashreport',
#    'content_suggest': ['Minister of Defense of Ukraine: "New BayraktarTB2s have already arrived in Ukraine and are at combat positions https://t.co/46ahoqzxMd via @clashreport'],
#    'likes': 916,
#    'retweet': 223,
#    'latlon': '50.44127,30.47788',
#    'id': '57595bd2-6d3b-4eea-890a-0838790e9f0d',
#    'tweet_id': '1498929367967313920',
#    '_version_': 1728691942854754304},
#   {'created_at': '2022-02-24T06:03:28Z',
#    'username': 'Liveuamap',
#    'content': 'Ukrainian military says it shot down 5 Russian planes and Russian helicopter in Eastern Ukraine, Luhansk https://t.co/GSHeTymJXq via @ragipsoylu #Ukraine https://t.co/IdiK6NNIKd',
#    'content_suggest': ['Ukrainian military says it shot down 5 Russian planes and Russian helicopter in Eastern Ukraine, Luhansk https://t.co/GSHeTymJXq via @ragipsoylu #Ukraine https://t.co/IdiK6NNIKd'],
#    'likes': 464,
#    'retweet': 130,
#    'latlon': '50.44195,30.4771',
#    'id': 'a069b44c-66d8-404b-b8ca-9d61fb9542e0',
#    'tweet_id': '1496727458456178690',
#    '_version_': 1728691931859386368},
#   {'created_at': '2022-02-25T08:56:31Z',
#    'username': 'asya_wiz',
#    'content': '#Kyiv #Obolon it’s happening in #Ukraine now! https://t.co/V9mUD86lv2',
#    'content_suggest': ['#Kyiv #Obolon it’s happening in #Ukraine now! https://t.co/V9mUD86lv2'],
#    'likes': 8,
#    'retweet': 7,
#    'latlon': '50.482892080428584,30.526479059403123',
#    'id': '3ab0100e-0e1d-42da-a562-c26cf2598677',
#    'tweet_id': '1497133394911715344',
#    '_version_': 1728691933043228672},
#   {'created_at': '2022-02-24T04:48:57Z',
#    'username': 'theappstar',
#    'content': 'Hope to see this madness ending soon. Standing in solidarity with my friends in Ukraine 🇺🇦 🕊️\n\nPicture of The Motherland Monument, (Batkivshchýna-Máty), Kyiv, taken in 2018.\n\n#stopthismadness \n#postcardfromukraine #kyiv #ukraine #throwbackthursday https://t.co/sc3RRMt0nb',
#    'content_suggest': ['Hope to see this madness ending soon. Standing in solidarity with my friends in Ukraine 🇺🇦 🕊️\n\nPicture of The Motherland Monument, (Batkivshchýna-Máty), Kyiv, taken in 2018.\n\n#stopthismadness \n#postcardfromukraine #kyiv #ukraine #throwbackthursday https://t.co/sc3RRMt0nb'],
#    'likes': 4,
#    'retweet': 0,
#    'latlon': '50.426483306268224,30.56297779083252',
#    'id': '1519df40-c8ea-4e88-8eb6-4928a52ac5e0',
#    'tweet_id': '1496708705894936582',
#    '_version_': 1728691931868823552},
#   {'created_at': '2022-02-25T07:48:48Z',
#    'username': 'sferik',
#    'content': 'Photo of me in Kyiv from the summer of 2015 in front of a statue—50% taller than the Statue of Liberty—of a woman holding a sword and shield. I hope she continues standing tall, serving as a symbol of the strength and resilience of the people of Ukraine. https://t.co/kAG6F3t1UP',
#    'content_suggest': ['Photo of me in Kyiv from the summer of 2015 in front of a statue—50% taller than the Statue of Liberty—of a woman holding a sword and shield. I hope she continues standing tall, serving as a symbol of the strength and resilience of the people of Ukraine. https://t.co/kAG6F3t1UP'],
#    'likes': 20,
#    'retweet': 1,
#    'latlon': '50.426483306268224,30.56297779083252',
#    'id': '78f9d29e-1b0d-44ae-be97-c9a0d9a0b179',
#    'tweet_id': '1497116354867986432',
#    '_version_': 1728691933048471552},
#   {'created_at': '2022-02-25T17:52:27Z',
#    'username': 'DrHaryanvi',
#    'content': "STOP WAR ! STOP WAR ! STOP WAR .\npeople in ukraine are worried , tensed and don't feel safe .\n#Ukrainian #StopTheWar #StopPutinNOW #UkraineUnderAttack \n#indianstudentsinukraine\nTo see full video .\nYoutube - https://t.co/smT3u9RLkt https://t.co/OdpMERcfJU",
#    'content_suggest': ["STOP WAR ! STOP WAR ! STOP WAR .\npeople in ukraine are worried , tensed and don't feel safe .\n#Ukrainian #StopTheWar #StopPutinNOW #UkraineUnderAttack \n#indianstudentsinukraine\nTo see full video .\nYoutube - https://t.co/smT3u9RLkt https://t.co/OdpMERcfJU"],
#    'likes': 3,
#    'retweet': 1,
#    'latlon': '50.45079597686394,30.46631097793579',
#    'id': '21014b62-0e47-40a7-8c23-ab7e133694eb',
#    'tweet_id': '1497268268775706624',
#    '_version_': 1728691932942565376},
#   {'created_at': '2022-02-24T06:04:31Z',
#    'username': '_deepakgujjar_',
#    'content': 'We are stuck in Kiev, Ukraine. Many students are here we have our flights but they got cancelled as the airport is closed, we need help as we are hearing sirens continuously we need assurance for our safety and hoping for evacuation soon. @IndiainUkraine @PMOIndia @DrSJaishankar',
#    'content_suggest': ['We are stuck in Kiev, Ukraine. Many students are here we have our flights but they got cancelled as the airport is closed, we need help as we are hearing sirens continuously we need assurance for our safety and hoping for evacuation soon. @IndiainUkraine @PMOIndia @DrSJaishankar'],
#    'likes': 0,
#    'retweet': 0,
#    'latlon': '50.45134541021852,30.459647261731075',
#    'id': 'b7db3e55-9572-4ac7-b069-89fef314ab75',
#    'tweet_id': '1496727722176962561',
#    '_version_': 1728691931854143488},
#   {'created_at': '2022-02-24T23:42:59Z',
#    'username': 'ocho88888888',
#    'content': 'It was really special those days. Only good things for me during my visit. Ukraine 🇺🇦 must stay Ukraine. So easy. Fucking lies, Fucking russian invasion. Thanks for every russian raising the voice against a totally nuts leader.\n@klattius #StandWithUkraine \n#Kiew #fckptn https://t.co/mcaIBVqJnz',
#    'content_suggest': ['It was really special those days. Only good things for me during my visit. Ukraine 🇺🇦 must stay Ukraine. So easy. Fucking lies, Fucking russian invasion. Thanks for every russian raising the voice against a totally nuts leader.\n@klattius #StandWithUkraine \n#Kiew #fckptn https://t.co/mcaIBVqJnz'],
#    'likes': 15,
#    'retweet': 0,
#    'latlon': '50.491602,30.499839',
#    'id': '79193a66-a0f4-490f-afe8-ba7535a350b0',
#    'tweet_id': '1496994093985157127',
#    '_version_': 1728691931617165312}],
#  281)
